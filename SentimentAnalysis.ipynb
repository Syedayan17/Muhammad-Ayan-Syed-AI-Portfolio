# %% [markdown]
# <a href="https://colab.research.google.com/github/Syedayan17/Muhammad-Ayan-Syed-AI-Portfolio/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis (NLP)
# Classify text as positive or negative.

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
text = 'I love this AI course, it is very helpful!'

# %%
analysis = TextBlob(text)

if analysis.sentiment.polarity > 0:
    print('Positive Sentiment')
else:
    print('Negative Sentiment')
# Out:
# Positive Sentiment
